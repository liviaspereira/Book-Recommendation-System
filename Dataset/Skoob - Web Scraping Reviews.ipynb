# %%
# Data Analysis Libraries
import pandas as pd
import numpy as np
import math

# Web Scrapping Libraries
import requests
from bs4 import BeautifulSoup

pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_columns',None)

# %%
url_resenhas = 'https://www.skoob.com.br/livro/resenhas/{}/mais-gostaram/mpage:{}' 
# página do Skoob em que constam as resenhas, em que o primeiro {} será o número do livro e o segundo {} a página de reviews

# %%
def raspar_skoob(livro_inicial, livro_final, limite,imprimir):
    # livro_inicial: primeiro livro a ser coletado (número inteiro não nulo)
    # livro_final: ultimo livro a ser coletado, incluindo-o (sendo necessáriamente um número maior que o do livro_inicial)
    # limite: limite de reviews a serem coletados. 
        # Caso o valor seja menor que o número de reviews existentes, ele limitárá o total
        # Caso insira um valor maior que o número de reviews disponíveis, ele pegará o máximo existente
        # Caso não deseje limitar, inserir o valor 0
    # imprimir: se True, irá printar os estágios, se False, não irá printar os estágios
    
    lista_completa = [] # lista com output de todas as reviews coletadas
    lista_livros = [] # lista dos livros coletados
    
    
    # range da lista de livros, começando no livro_inicial até livro_final, em que será feita a coleta
    for i in range(livro_inicial,livro_final+1): 
        response = requests.get(url_resenhas.format(i,'1'))
        pagina_html = BeautifulSoup(response.text)
        corpo = pagina_html.findAll(id="corpo") # corpo da página a ser feita a raspagem de dados (Web Scraping)
        
        try: # testar se existe um livro naquela posição, caso não exista simplesmente passará para o próximo livro
            
            Livro = corpo[0].findAll('strong')[0].get_text() # Nome do Livro
            Autor = corpo[0].findAll('a')[1].get_text() # Nome do Autor 
            
            # Salvar o livro, após verificar que existem livros
            lista_livros.append({'author':Autor,
                                 'book':Livro,
                                 'link':'https://www.skoob.com.br/livro/resenhas/{}/mais-gostaram/mpage:{}'.format(i,'1'),
                                 'livro_numero':i})
            
            try: # testar se existe alguma reviews para este livro, se não houver, anotará o livro mas com reviews vazias (None)

                # calculando número de páginas com comentários
                total_pags = math.ceil(int(corpo[0].findAll(id="perfil-conteudo-intern")[0].findAll('b')[0].get_text().split(' ')[0])/15)
                
                if limite == 0: # se limite for definido como 0, pegará todas os comentários existentes   
                    pass            
                elif total_pags > math.ceil(limite/15): # se houverem mais páginas que as necessárias para encontrar o limite
                    total_pags = math.ceil(limite/15) # limitará as páginas de modo a limitar o total de comentários
                else:
                    pass # se não for 0 nem maior que o existente, teremos menos reviews que o desejado, portanto pegaremos todos os disponíveis
                
                if imprimir: # se True, irá printar o livro que está sendo coletado
                    # printando nome do livro e indice do site, para identificar casos de bug
                    print('Livro {}: {}'.format(i, Livro)) 
                
                contagem  = 0 # definindo um contador de comentários por livro
                
                for paginas in range(1,total_pags+1): # range das páginas com comentários, seguindo limite caso tenha sido definido
                    response2 = requests.get(url_resenhas.format(i,paginas))
                    pagina_html2 = BeautifulSoup(response2.text)
                    corpo2 = pagina_html2.findAll(id="corpo") # corpo das reviews de cada página
                    
                    if imprimir: # se True, irá printar o livro e página que está sendo coletado
                        print('Livro {}: {} - Página: {}'.format(i, Livro, paginas)) # printando página da review, para identificar casos de bug
                    
                    # existem até 15 reviews por página, cada uma com o ID da review aparecendo 2x, portanto
                    # o range padrão de coleta de comentários por página vai de 0 a 29, pulando de 2 em 2
                    # no entanto, possívelmente ele foi limitado
                    
                    if (paginas == math.ceil(limite/15) and limite!= 0): # se a página atual for a mesma definida ao limitar
                        ultima_review = limite-contagem # encontrar quantas reviews ainda serão coletadas para atingir limite definido
                        ultima_review = ultima_review*2
                    else:
                        ultima_review = 30 # se nao estiver no limite definido, usará o range completo das reviews
                    
                    for resenhas in range(0,ultima_review,2):                       
                            
                        try: # testar se existe comentário nesta posição, uma vez que se nao tiver sido limitado, 
                             # na última página de comentários pode haver menos de 15
                            if imprimir: # se True, irá printar o livro e página e review que está sendo coletado
                                print('Livro {}: {} - Página: {} - Review: {}'.format(i, Livro, paginas,int(resenhas/2+1))) # printando a posição da review, para identificar casos de bug
                            
                            # dados gerais da resenha    
                            review_pt1 = corpo2[0].findAll(id="perfil-conteudo-intern")[0].findAll("div", id=lambda value: value and value.startswith("resenha"))[resenhas]
                            
                            Link = 'https://www.skoob.com.br/livro/resenhas/{}/mais-gostaram/mpage:{}'.format(i,paginas) # link da review
                            id_resenha = review_pt1.get('id') # ID da review
                            id_usuario = review_pt1.find('a').get('href').split('/')[-1] # ID do usuário
                            nota = float(review_pt1.find('star-rating').get('rate')) # Nota dada pelo usuário
                            
                            # dados de texto da resenha
                            review_pt2 = corpo2[0].findAll(id="perfil-conteudo-intern")[0].findAll("div", id=lambda value: value and value.startswith("resenha"))[resenhas+1]
                            
                            try: # caso exista um título, salvar ele separadamente
                                titulo = review_pt2.findAll('strong')[1].get_text() 
                            except IndexError: # caso não exista um título, salvar None
                                titulo = None
                                
                            resenha = review_pt2.get_text() # obtendo o texto que consta título, data e resenha
                            
                            # na estrutura obtida, caso exista um titulo, ele é a ultima informação antes da resenha em si
                            # caso não exista um título, a data é a ultima informação
                            if titulo == None: # caso não haja um título, usar a data como divisor para obter apenas a resenha
                                resenha = resenha.split('/',2)[-1][4:]
                            else: # caso haja um título, utilizá-lo como divisor para obter a resenha
                                resenha = resenha.split(titulo,1)[1]
                
                            # salvar as resenhas na lista de resenhas
                            lista_completa.append({'author':Autor,
                                                   'book':Livro,
                                                   'link':Link,
                                                   'review_id': id_resenha,
                                                   'user_id': id_usuario,
                                                   'livro_pagina_posicao':'{}-{}-{}'.format(i,paginas,int(resenhas/2+1)),
                                                   'rating': nota,
                                                   'review_title': titulo,
                                                   'review': resenha})
                            contagem+=1
                            
                        except IndexError: # caso não exista um comentário nessa posição, irá quebrar o loop, mudanodo de livro
                            break
            except IndexError: # no caso do livro não ter comentários, salvará o livro sem comentários
                lista_completa.append({'author':Autor,
                                       'book':Livro,
                                       'link':'https://www.skoob.com.br/livro/resenhas/{}/mais-gostaram/mpage:{}'.format(i,'1'),
                                       'review_id': None,
                                       'user_id': None,
                                       'livro_pagina_posicao':'{}-{}-{}'.format(1,1,0),
                                       'rating': None,
                                       'review_title': None,
                                       'review': None})
                
        except IndexError: # caso não exista um livro nesta página, passar para próximo livro
            pass
    return(lista_completa, lista_livros)

# %%
reviews, livros = raspar_skoob(1,20,35,True)
# Out:
# Livro 1: Ensaio Sobre a Cegueira
# Livro 1: Ensaio Sobre a Cegueira - Página: 1
# Livro 1: Ensaio Sobre a Cegueira - Página: 1 - Review: 1
# Livro 1: Ensaio Sobre a Cegueira - Página: 1 - Review: 2
# Livro 1: Ensaio Sobre a Cegueira - Página: 1 - Review: 3
# Livro 1: Ensaio Sobre a Cegueira - Página: 1 - Review: 4
# Livro 1: Ensaio Sobre a Cegueira - Página: 1 - Review: 5
# Livro 1: Ensaio Sobre a Cegueira - Página: 1 - Review: 6
# Livro 1: Ensaio Sobre a Cegueira - Página: 1 - Review: 7
# Livro 1: Ensaio Sobre a Cegueira - Página: 1 - Review: 8
# Livro 1: Ensaio Sobre a Cegueira - Página: 1 - Review: 9
# Livro 1: Ensaio Sobre a Cegueira - Página: 1 - Review: 10
# Livro 1: Ensaio Sobre a Cegueira - Página: 1 - Review: 11
# Livro 1: Ensaio Sobre a Cegueira - Página: 1 - Review: 12
# Livro 1: Ensaio Sobre a Cegueira - Página: 1 - Review: 13
# Livro 1: Ensaio Sobre a Cegueira - Página: 1 - Review: 14
# Livro 1: Ensaio Sobre a Cegueira - Página: 1 - Review: 15
# Livro 1: Ensaio Sobre a Cegueira - Página: 2
# Livro 1: Ensaio Sobre a Cegueira - Página: 2 - Review: 1
# Livro 1: Ensaio Sobre a Cegueira - Página: 2 - Review: 2
# Livro 1: Ensaio Sobre a Cegueira - Página: 2 - Review: 3
# Livro 1: Ensaio Sobre a Cegueira - Página: 2 - Review: 4
# Livro 1: Ensaio Sobre a Cegueira - Página: 2 - Review: 5
# Livro 1: Ensaio Sobre a Cegueira - Página: 2 - Review: 6
# Livro 1: Ensaio Sobre a Cegueira - Página: 2 - Review: 7
# Livro 1: Ensaio Sobre a Cegueira - Página: 2 - Review: 8
# Livro 1: Ensaio Sobre a Cegueira - Página: 2 - Review: 9
# Livro 1: Ensaio Sobre a Cegueira - Página: 2 - Review: 10
# Livro 1: Ensaio Sobre a Cegueira - Página: 2 - Review: 11
# Livro 1: Ensaio Sobre a Cegueira - Página: 2 - Review: 12
# Livro 1: Ensaio Sobre a Cegueira - Página: 2 - Review: 13
# Livro 1: Ensaio Sobre a Cegueira - Página: 2 - Review: 14
# Livro 1: Ensaio Sobre a Cegueira - Página: 2 - Review: 15
# Livro 1: Ensaio Sobre a Cegueira - Página: 3
# Livro 1: Ensaio Sobre a Cegueira - Página: 3 - Review: 1
# Livro 1: Ensaio Sobre a Cegueira - Página: 3 - Review: 2
# Livro 1: Ensaio Sobre a Cegueira - Página: 3 - Review: 3
# Livro 1: Ensaio Sobre a Cegueira - Página: 3 - Review: 4
# Livro 1: Ensaio Sobre a Cegueira - Página: 3 - Review: 5
# Livro 2: O Caçador de Pipas
# Livro 2: O Caçador de Pipas - Página: 1
# Livro 2: O Caçador de Pipas - Página: 1 - Review: 1
# Livro 2: O Caçador de Pipas - Página: 1 - Review: 2
# Livro 2: O Caçador de Pipas - Página: 1 - Review: 3
# Livro 2: O Caçador de Pipas - Página: 1 - Review: 4
# Livro 2: O Caçador de Pipas - Página: 1 - Review: 5
# Livro 2: O Caçador de Pipas - Página: 1 - Review: 6
# Livro 2: O Caçador de Pipas - Página: 1 - Review: 7
# Livro 2: O Caçador de Pipas - Página: 1 - Review: 8
# Livro 2: O Caçador de Pipas - Página: 1 - Review: 9
# Livro 2: O Caçador de Pipas - Página: 1 - Review: 10
# Livro 2: O Caçador de Pipas - Página: 1 - Review: 11
# Livro 2: O Caçador de Pipas - Página: 1 - Review: 12
# Livro 2: O Caçador de Pipas - Página: 1 - Review: 13
# Livro 2: O Caçador de Pipas - Página: 1 - Review: 14
# Livro 2: O Caçador de Pipas - Página: 1 - Review: 15
# Livro 2: O Caçador de Pipas - Página: 2
# Livro 2: O Caçador de Pipas - Página: 2 - Review: 1
# Livro 2: O Caçador de Pipas - Página: 2 - Review: 2
# Livro 2: O Caçador de Pipas - Página: 2 - Review: 3
# Livro 2: O Caçador de Pipas - Página: 2 - Review: 4
# Livro 2: O Caçador de Pipas - Página: 2 - Review: 5
# Livro 2: O Caçador de Pipas - Página: 2 - Review: 6
# Livro 2: O Caçador de Pipas - Página: 2 - Review: 7
# Livro 2: O Caçador de Pipas - Página: 2 - Review: 8
# Livro 2: O Caçador de Pipas - Página: 2 - Review: 9
# Livro 2: O Caçador de Pipas - Página: 2 - Review: 10
# Livro 2: O Caçador de Pipas - Página: 2 - Review: 11
# Livro 2: O Caçador de Pipas - Página: 2 - Review: 12
# Livro 2: O Caçador de Pipas - Página: 2 - Review: 13
# Livro 2: O Caçador de Pipas - Página: 2 - Review: 14
# Livro 2: O Caçador de Pipas - Página: 2 - Review: 15
# Livro 2: O Caçador de Pipas - Página: 3
# Livro 2: O Caçador de Pipas - Página: 3 - Review: 1
# Livro 2: O Caçador de Pipas - Página: 3 - Review: 2
# Livro 2: O Caçador de Pipas - Página: 3 - Review: 3
# Livro 2: O Caçador de Pipas - Página: 3 - Review: 4
# Livro 2: O Caçador de Pipas - Página: 3 - Review: 5
# Livro 3: O Alquimista
# Livro 3: O Alquimista - Página: 1
# Livro 3: O Alquimista - Página: 1 - Review: 1
# Livro 3: O Alquimista - Página: 1 - Review: 2
# Livro 3: O Alquimista - Página: 1 - Review: 3
# Livro 3: O Alquimista - Página: 1 - Review: 4
# Livro 3: O Alquimista - Página: 1 - Review: 5
# Livro 3: O Alquimista - Página: 1 - Review: 6
# Livro 3: O Alquimista - Página: 1 - Review: 7
# Livro 3: O Alquimista - Página: 1 - Review: 8
# Livro 3: O Alquimista - Página: 1 - Review: 9
# Livro 3: O Alquimista - Página: 1 - Review: 10
# Livro 3: O Alquimista - Página: 1 - Review: 11
# Livro 3: O Alquimista - Página: 1 - Review: 12
# Livro 3: O Alquimista - Página: 1 - Review: 13
# Livro 3: O Alquimista - Página: 1 - Review: 14
# Livro 3: O Alquimista - Página: 1 - Review: 15
# Livro 3: O Alquimista - Página: 2
# Livro 3: O Alquimista - Página: 2 - Review: 1
# Livro 3: O Alquimista - Página: 2 - Review: 2
# Livro 3: O Alquimista - Página: 2 - Review: 3
# Livro 3: O Alquimista - Página: 2 - Review: 4
# Livro 3: O Alquimista - Página: 2 - Review: 5
# Livro 3: O Alquimista - Página: 2 - Review: 6
# Livro 3: O Alquimista - Página: 2 - Review: 7
# Livro 3: O Alquimista - Página: 2 - Review: 8
# Livro 3: O Alquimista - Página: 2 - Review: 9
# Livro 3: O Alquimista - Página: 2 - Review: 10
# Livro 3: O Alquimista - Página: 2 - Review: 11
# Livro 3: O Alquimista - Página: 2 - Review: 12
# Livro 3: O Alquimista - Página: 2 - Review: 13
# Livro 3: O Alquimista - Página: 2 - Review: 14
# Livro 3: O Alquimista - Página: 2 - Review: 15
# Livro 3: O Alquimista - Página: 3
# Livro 3: O Alquimista - Página: 3 - Review: 1
# Livro 3: O Alquimista - Página: 3 - Review: 2
# Livro 3: O Alquimista - Página: 3 - Review: 3
# Livro 3: O Alquimista - Página: 3 - Review: 4
# Livro 3: O Alquimista - Página: 3 - Review: 5
# Livro 3: O Alquimista - Página: 3 - Review: 6
# Livro 4: Fernão Capelo Gaivota
# Livro 4: Fernão Capelo Gaivota - Página: 1
# Livro 4: Fernão Capelo Gaivota - Página: 1 - Review: 1
# Livro 4: Fernão Capelo Gaivota - Página: 1 - Review: 2
# Livro 4: Fernão Capelo Gaivota - Página: 1 - Review: 3
# Livro 4: Fernão Capelo Gaivota - Página: 1 - Review: 4
# Livro 4: Fernão Capelo Gaivota - Página: 1 - Review: 5
# Livro 4: Fernão Capelo Gaivota - Página: 1 - Review: 6
# Livro 4: Fernão Capelo Gaivota - Página: 1 - Review: 7
# Livro 4: Fernão Capelo Gaivota - Página: 1 - Review: 8
# Livro 4: Fernão Capelo Gaivota - Página: 1 - Review: 9
# Livro 4: Fernão Capelo Gaivota - Página: 1 - Review: 10
# Livro 4: Fernão Capelo Gaivota - Página: 1 - Review: 11
# Livro 4: Fernão Capelo Gaivota - Página: 1 - Review: 12
# Livro 4: Fernão Capelo Gaivota - Página: 1 - Review: 13
# Livro 4: Fernão Capelo Gaivota - Página: 1 - Review: 14
# Livro 4: Fernão Capelo Gaivota - Página: 1 - Review: 15
# Livro 4: Fernão Capelo Gaivota - Página: 2
# Livro 4: Fernão Capelo Gaivota - Página: 2 - Review: 1
# Livro 4: Fernão Capelo Gaivota - Página: 2 - Review: 2
# Livro 4: Fernão Capelo Gaivota - Página: 2 - Review: 3
# Livro 4: Fernão Capelo Gaivota - Página: 2 - Review: 4
# Livro 4: Fernão Capelo Gaivota - Página: 2 - Review: 5
# Livro 4: Fernão Capelo Gaivota - Página: 2 - Review: 6
# Livro 4: Fernão Capelo Gaivota - Página: 2 - Review: 7
# Livro 4: Fernão Capelo Gaivota - Página: 2 - Review: 8
# Livro 4: Fernão Capelo Gaivota - Página: 2 - Review: 9
# Livro 4: Fernão Capelo Gaivota - Página: 2 - Review: 10
# Livro 4: Fernão Capelo Gaivota - Página: 2 - Review: 11
# Livro 4: Fernão Capelo Gaivota - Página: 2 - Review: 12
# Livro 4: Fernão Capelo Gaivota - Página: 2 - Review: 13
# Livro 4: Fernão Capelo Gaivota - Página: 2 - Review: 14
# Livro 4: Fernão Capelo Gaivota - Página: 2 - Review: 15
# Livro 4: Fernão Capelo Gaivota - Página: 3
# Livro 4: Fernão Capelo Gaivota - Página: 3 - Review: 1
# Livro 4: Fernão Capelo Gaivota - Página: 3 - Review: 2
# Livro 4: Fernão Capelo Gaivota - Página: 3 - Review: 3
# Livro 4: Fernão Capelo Gaivota - Página: 3 - Review: 4
# Livro 4: Fernão Capelo Gaivota - Página: 3 - Review: 5
# Livro 5: Operação Cavalo de Tróia 1
# Livro 5: Operação Cavalo de Tróia 1 - Página: 1
# Livro 5: Operação Cavalo de Tróia 1 - Página: 1 - Review: 1
# Livro 5: Operação Cavalo de Tróia 1 - Página: 1 - Review: 2
# Livro 5: Operação Cavalo de Tróia 1 - Página: 1 - Review: 3
# Livro 5: Operação Cavalo de Tróia 1 - Página: 1 - Review: 4
# Livro 5: Operação Cavalo de Tróia 1 - Página: 1 - Review: 5
# Livro 5: Operação Cavalo de Tróia 1 - Página: 1 - Review: 6
# Livro 5: Operação Cavalo de Tróia 1 - Página: 1 - Review: 7
# Livro 5: Operação Cavalo de Tróia 1 - Página: 1 - Review: 8
# Livro 5: Operação Cavalo de Tróia 1 - Página: 1 - Review: 9
# Livro 5: Operação Cavalo de Tróia 1 - Página: 1 - Review: 10
# Livro 5: Operação Cavalo de Tróia 1 - Página: 1 - Review: 11
# Livro 5: Operação Cavalo de Tróia 1 - Página: 1 - Review: 12
# Livro 5: Operação Cavalo de Tróia 1 - Página: 1 - Review: 13
# Livro 5: Operação Cavalo de Tróia 1 - Página: 1 - Review: 14
# Livro 5: Operação Cavalo de Tróia 1 - Página: 1 - Review: 15
# Livro 5: Operação Cavalo de Tróia 1 - Página: 2
# Livro 5: Operação Cavalo de Tróia 1 - Página: 2 - Review: 1
# Livro 5: Operação Cavalo de Tróia 1 - Página: 2 - Review: 2
# Livro 5: Operação Cavalo de Tróia 1 - Página: 2 - Review: 3
# Livro 5: Operação Cavalo de Tróia 1 - Página: 2 - Review: 4
# Livro 5: Operação Cavalo de Tróia 1 - Página: 2 - Review: 5
# Livro 5: Operação Cavalo de Tróia 1 - Página: 2 - Review: 6
# Livro 5: Operação Cavalo de Tróia 1 - Página: 2 - Review: 7
# Livro 5: Operação Cavalo de Tróia 1 - Página: 2 - Review: 8
# Livro 5: Operação Cavalo de Tróia 1 - Página: 2 - Review: 9
# Livro 5: Operação Cavalo de Tróia 1 - Página: 2 - Review: 10
# Livro 5: Operação Cavalo de Tróia 1 - Página: 2 - Review: 11
# Livro 5: Operação Cavalo de Tróia 1 - Página: 2 - Review: 12
# Livro 5: Operação Cavalo de Tróia 1 - Página: 2 - Review: 13
# Livro 5: Operação Cavalo de Tróia 1 - Página: 2 - Review: 14
# Livro 5: Operação Cavalo de Tróia 1 - Página: 2 - Review: 15
# Livro 5: Operação Cavalo de Tróia 1 - Página: 3
# Livro 5: Operação Cavalo de Tróia 1 - Página: 3 - Review: 1
# Livro 5: Operação Cavalo de Tróia 1 - Página: 3 - Review: 2
# Livro 5: Operação Cavalo de Tróia 1 - Página: 3 - Review: 3
# Livro 5: Operação Cavalo de Tróia 1 - Página: 3 - Review: 4
# Livro 5: Operação Cavalo de Tróia 1 - Página: 3 - Review: 5
# Livro 5: Operação Cavalo de Tróia 1 - Página: 3 - Review: 6
# Livro 5: Operação Cavalo de Tróia 1 - Página: 3 - Review: 7
# Livro 6: Ilusões
# Livro 6: Ilusões - Página: 1
# Livro 6: Ilusões - Página: 1 - Review: 1
# Livro 6: Ilusões - Página: 1 - Review: 2
# Livro 6: Ilusões - Página: 1 - Review: 3
# Livro 6: Ilusões - Página: 1 - Review: 4
# Livro 6: Ilusões - Página: 1 - Review: 5
# Livro 6: Ilusões - Página: 1 - Review: 6
# Livro 6: Ilusões - Página: 1 - Review: 7
# Livro 6: Ilusões - Página: 1 - Review: 8
# Livro 6: Ilusões - Página: 1 - Review: 9
# Livro 6: Ilusões - Página: 1 - Review: 10
# Livro 6: Ilusões - Página: 1 - Review: 11
# Livro 6: Ilusões - Página: 1 - Review: 12
# Livro 6: Ilusões - Página: 1 - Review: 13
# Livro 6: Ilusões - Página: 1 - Review: 14
# Livro 6: Ilusões - Página: 1 - Review: 15
# Livro 6: Ilusões - Página: 2
# Livro 6: Ilusões - Página: 2 - Review: 1
# Livro 6: Ilusões - Página: 2 - Review: 2
# Livro 6: Ilusões - Página: 2 - Review: 3
# Livro 6: Ilusões - Página: 2 - Review: 4
# Livro 6: Ilusões - Página: 2 - Review: 5
# Livro 6: Ilusões - Página: 2 - Review: 6
# Livro 6: Ilusões - Página: 2 - Review: 7
# Livro 6: Ilusões - Página: 2 - Review: 8
# Livro 6: Ilusões - Página: 2 - Review: 9
# Livro 6: Ilusões - Página: 2 - Review: 10
# Livro 6: Ilusões - Página: 2 - Review: 11
# Livro 6: Ilusões - Página: 2 - Review: 12
# Livro 6: Ilusões - Página: 2 - Review: 13
# Livro 6: Ilusões - Página: 2 - Review: 14
# Livro 6: Ilusões - Página: 2 - Review: 15
# Livro 6: Ilusões - Página: 3
# Livro 6: Ilusões - Página: 3 - Review: 1
# Livro 6: Ilusões - Página: 3 - Review: 2
# Livro 6: Ilusões - Página: 3 - Review: 3
# Livro 6: Ilusões - Página: 3 - Review: 4
# Livro 6: Ilusões - Página: 3 - Review: 5
# Livro 6: Ilusões - Página: 3 - Review: 6
# Livro 7: A Menina que Roubava Livros
# Livro 7: A Menina que Roubava Livros - Página: 1
# Livro 7: A Menina que Roubava Livros - Página: 1 - Review: 1
# Livro 7: A Menina que Roubava Livros - Página: 1 - Review: 2
# Livro 7: A Menina que Roubava Livros - Página: 1 - Review: 3
# Livro 7: A Menina que Roubava Livros - Página: 1 - Review: 4
# Livro 7: A Menina que Roubava Livros - Página: 1 - Review: 5
# Livro 7: A Menina que Roubava Livros - Página: 1 - Review: 6
# Livro 7: A Menina que Roubava Livros - Página: 1 - Review: 7
# Livro 7: A Menina que Roubava Livros - Página: 1 - Review: 8
# Livro 7: A Menina que Roubava Livros - Página: 1 - Review: 9
# Livro 7: A Menina que Roubava Livros - Página: 1 - Review: 10
# Livro 7: A Menina que Roubava Livros - Página: 1 - Review: 11
# Livro 7: A Menina que Roubava Livros - Página: 1 - Review: 12
# Livro 7: A Menina que Roubava Livros - Página: 1 - Review: 13
# Livro 7: A Menina que Roubava Livros - Página: 1 - Review: 14
# Livro 7: A Menina que Roubava Livros - Página: 1 - Review: 15
# Livro 7: A Menina que Roubava Livros - Página: 2
# Livro 7: A Menina que Roubava Livros - Página: 2 - Review: 1
# Livro 7: A Menina que Roubava Livros - Página: 2 - Review: 2
# Livro 7: A Menina que Roubava Livros - Página: 2 - Review: 3
# Livro 7: A Menina que Roubava Livros - Página: 2 - Review: 4
# Livro 7: A Menina que Roubava Livros - Página: 2 - Review: 5
# Livro 7: A Menina que Roubava Livros - Página: 2 - Review: 6
# Livro 7: A Menina que Roubava Livros - Página: 2 - Review: 7
# Livro 7: A Menina que Roubava Livros - Página: 2 - Review: 8
# Livro 7: A Menina que Roubava Livros - Página: 2 - Review: 9
# Livro 7: A Menina que Roubava Livros - Página: 2 - Review: 10
# Livro 7: A Menina que Roubava Livros - Página: 2 - Review: 11
# Livro 7: A Menina que Roubava Livros - Página: 2 - Review: 12
# Livro 7: A Menina que Roubava Livros - Página: 2 - Review: 13
# Livro 7: A Menina que Roubava Livros - Página: 2 - Review: 14
# Livro 7: A Menina que Roubava Livros - Página: 2 - Review: 15
# Livro 7: A Menina que Roubava Livros - Página: 3
# Livro 7: A Menina que Roubava Livros - Página: 3 - Review: 1
# Livro 7: A Menina que Roubava Livros - Página: 3 - Review: 2
# Livro 7: A Menina que Roubava Livros - Página: 3 - Review: 3
# Livro 7: A Menina que Roubava Livros - Página: 3 - Review: 4
# Livro 7: A Menina que Roubava Livros - Página: 3 - Review: 5
# Livro 7: A Menina que Roubava Livros - Página: 3 - Review: 6
# Livro 8: Atitude
# Livro 8: Atitude - Página: 1
# Livro 8: Atitude - Página: 1 - Review: 1
# Livro 8: Atitude - Página: 1 - Review: 2
# Livro 8: Atitude - Página: 1 - Review: 3
# Livro 8: Atitude - Página: 1 - Review: 4
# Livro 8: Atitude - Página: 1 - Review: 5
# Livro 10: Investimentos
# Livro 10: Investimentos - Página: 1
# Livro 10: Investimentos - Página: 1 - Review: 1
# Livro 10: Investimentos - Página: 1 - Review: 2
# Livro 10: Investimentos - Página: 1 - Review: 3
# Livro 10: Investimentos - Página: 1 - Review: 4
# Livro 10: Investimentos - Página: 1 - Review: 5
# Livro 10: Investimentos - Página: 1 - Review: 6
# Livro 10: Investimentos - Página: 1 - Review: 7
# Livro 10: Investimentos - Página: 1 - Review: 8
# Livro 10: Investimentos - Página: 1 - Review: 9
# Livro 10: Investimentos - Página: 1 - Review: 10
# Livro 10: Investimentos - Página: 1 - Review: 11
# Livro 10: Investimentos - Página: 1 - Review: 12
# Livro 10: Investimentos - Página: 1 - Review: 13
# Livro 10: Investimentos - Página: 1 - Review: 14
# Livro 10: Investimentos - Página: 1 - Review: 15
# Livro 10: Investimentos - Página: 2
# Livro 10: Investimentos - Página: 2 - Review: 1
# Livro 10: Investimentos - Página: 2 - Review: 2
# Livro 10: Investimentos - Página: 2 - Review: 3
# Livro 10: Investimentos - Página: 2 - Review: 4
# Livro 10: Investimentos - Página: 2 - Review: 5
# Livro 10: Investimentos - Página: 2 - Review: 6
# Livro 11: Pai Rico Pai Pobre
# Livro 11: Pai Rico Pai Pobre - Página: 1
# Livro 11: Pai Rico Pai Pobre - Página: 1 - Review: 1
# Livro 11: Pai Rico Pai Pobre - Página: 1 - Review: 2
# Livro 11: Pai Rico Pai Pobre - Página: 1 - Review: 3
# Livro 11: Pai Rico Pai Pobre - Página: 1 - Review: 4
# Livro 11: Pai Rico Pai Pobre - Página: 1 - Review: 5
# Livro 11: Pai Rico Pai Pobre - Página: 1 - Review: 6
# Livro 11: Pai Rico Pai Pobre - Página: 1 - Review: 7
# Livro 11: Pai Rico Pai Pobre - Página: 1 - Review: 8
# Livro 11: Pai Rico Pai Pobre - Página: 1 - Review: 9
# Livro 11: Pai Rico Pai Pobre - Página: 1 - Review: 10
# Livro 11: Pai Rico Pai Pobre - Página: 1 - Review: 11
# Livro 11: Pai Rico Pai Pobre - Página: 1 - Review: 12
# Livro 11: Pai Rico Pai Pobre - Página: 1 - Review: 13
# Livro 11: Pai Rico Pai Pobre - Página: 1 - Review: 14
# Livro 11: Pai Rico Pai Pobre - Página: 1 - Review: 15
# Livro 11: Pai Rico Pai Pobre - Página: 2
# Livro 11: Pai Rico Pai Pobre - Página: 2 - Review: 1
# Livro 11: Pai Rico Pai Pobre - Página: 2 - Review: 2
# Livro 11: Pai Rico Pai Pobre - Página: 2 - Review: 3
# Livro 11: Pai Rico Pai Pobre - Página: 2 - Review: 4
# Livro 11: Pai Rico Pai Pobre - Página: 2 - Review: 5
# Livro 11: Pai Rico Pai Pobre - Página: 2 - Review: 6
# Livro 11: Pai Rico Pai Pobre - Página: 2 - Review: 7
# Livro 11: Pai Rico Pai Pobre - Página: 2 - Review: 8
# Livro 11: Pai Rico Pai Pobre - Página: 2 - Review: 9
# Livro 11: Pai Rico Pai Pobre - Página: 2 - Review: 10
# Livro 11: Pai Rico Pai Pobre - Página: 2 - Review: 11
# Livro 11: Pai Rico Pai Pobre - Página: 2 - Review: 12
# Livro 11: Pai Rico Pai Pobre - Página: 2 - Review: 13
# Livro 11: Pai Rico Pai Pobre - Página: 2 - Review: 14
# Livro 11: Pai Rico Pai Pobre - Página: 2 - Review: 15
# Livro 11: Pai Rico Pai Pobre - Página: 3
# Livro 11: Pai Rico Pai Pobre - Página: 3 - Review: 1
# Livro 11: Pai Rico Pai Pobre - Página: 3 - Review: 2
# Livro 11: Pai Rico Pai Pobre - Página: 3 - Review: 3
# Livro 11: Pai Rico Pai Pobre - Página: 3 - Review: 4
# Livro 11: Pai Rico Pai Pobre - Página: 3 - Review: 5
# Livro 12: Quem Mexeu No Meu Queijo?
# Livro 12: Quem Mexeu No Meu Queijo? - Página: 1
# Livro 12: Quem Mexeu No Meu Queijo? - Página: 1 - Review: 1
# Livro 12: Quem Mexeu No Meu Queijo? - Página: 1 - Review: 2
# Livro 12: Quem Mexeu No Meu Queijo? - Página: 1 - Review: 3
# Livro 12: Quem Mexeu No Meu Queijo? - Página: 1 - Review: 4
# Livro 12: Quem Mexeu No Meu Queijo? - Página: 1 - Review: 5
# Livro 12: Quem Mexeu No Meu Queijo? - Página: 1 - Review: 6
# Livro 12: Quem Mexeu No Meu Queijo? - Página: 1 - Review: 7
# Livro 12: Quem Mexeu No Meu Queijo? - Página: 1 - Review: 8
# Livro 12: Quem Mexeu No Meu Queijo? - Página: 1 - Review: 9
# Livro 12: Quem Mexeu No Meu Queijo? - Página: 1 - Review: 10
# Livro 12: Quem Mexeu No Meu Queijo? - Página: 1 - Review: 11
# Livro 12: Quem Mexeu No Meu Queijo? - Página: 1 - Review: 12
# Livro 12: Quem Mexeu No Meu Queijo? - Página: 1 - Review: 13
# Livro 12: Quem Mexeu No Meu Queijo? - Página: 1 - Review: 14
# Livro 12: Quem Mexeu No Meu Queijo? - Página: 1 - Review: 15
# Livro 12: Quem Mexeu No Meu Queijo? - Página: 2
# Livro 12: Quem Mexeu No Meu Queijo? - Página: 2 - Review: 1
# Livro 12: Quem Mexeu No Meu Queijo? - Página: 2 - Review: 2
# Livro 12: Quem Mexeu No Meu Queijo? - Página: 2 - Review: 3
# Livro 12: Quem Mexeu No Meu Queijo? - Página: 2 - Review: 4
# Livro 12: Quem Mexeu No Meu Queijo? - Página: 2 - Review: 5
# Livro 12: Quem Mexeu No Meu Queijo? - Página: 2 - Review: 6
# Livro 12: Quem Mexeu No Meu Queijo? - Página: 2 - Review: 7
# Livro 12: Quem Mexeu No Meu Queijo? - Página: 2 - Review: 8
# Livro 12: Quem Mexeu No Meu Queijo? - Página: 2 - Review: 9
# Livro 12: Quem Mexeu No Meu Queijo? - Página: 2 - Review: 10
# Livro 12: Quem Mexeu No Meu Queijo? - Página: 2 - Review: 11
# Livro 12: Quem Mexeu No Meu Queijo? - Página: 2 - Review: 12
# Livro 12: Quem Mexeu No Meu Queijo? - Página: 2 - Review: 13
# Livro 12: Quem Mexeu No Meu Queijo? - Página: 2 - Review: 14
# Livro 12: Quem Mexeu No Meu Queijo? - Página: 2 - Review: 15
# Livro 12: Quem Mexeu No Meu Queijo? - Página: 3
# Livro 12: Quem Mexeu No Meu Queijo? - Página: 3 - Review: 1
# Livro 12: Quem Mexeu No Meu Queijo? - Página: 3 - Review: 2
# Livro 12: Quem Mexeu No Meu Queijo? - Página: 3 - Review: 3
# Livro 12: Quem Mexeu No Meu Queijo? - Página: 3 - Review: 4
# Livro 12: Quem Mexeu No Meu Queijo? - Página: 3 - Review: 5
# Livro 13: Marley & Eu
# Livro 13: Marley & Eu - Página: 1
# Livro 13: Marley & Eu - Página: 1 - Review: 1
# Livro 13: Marley & Eu - Página: 1 - Review: 2
# Livro 13: Marley & Eu - Página: 1 - Review: 3
# Livro 13: Marley & Eu - Página: 1 - Review: 4
# Livro 13: Marley & Eu - Página: 1 - Review: 5
# Livro 13: Marley & Eu - Página: 1 - Review: 6
# Livro 13: Marley & Eu - Página: 1 - Review: 7
# Livro 13: Marley & Eu - Página: 1 - Review: 8
# Livro 13: Marley & Eu - Página: 1 - Review: 9
# Livro 13: Marley & Eu - Página: 1 - Review: 10
# Livro 13: Marley & Eu - Página: 1 - Review: 11
# Livro 13: Marley & Eu - Página: 1 - Review: 12
# Livro 13: Marley & Eu - Página: 1 - Review: 13
# Livro 13: Marley & Eu - Página: 1 - Review: 14
# Livro 13: Marley & Eu - Página: 1 - Review: 15
# Livro 13: Marley & Eu - Página: 2
# Livro 13: Marley & Eu - Página: 2 - Review: 1
# Livro 13: Marley & Eu - Página: 2 - Review: 2
# Livro 13: Marley & Eu - Página: 2 - Review: 3
# Livro 13: Marley & Eu - Página: 2 - Review: 4
# Livro 13: Marley & Eu - Página: 2 - Review: 5
# Livro 13: Marley & Eu - Página: 2 - Review: 6
# Livro 13: Marley & Eu - Página: 2 - Review: 7
# Livro 13: Marley & Eu - Página: 2 - Review: 8
# Livro 13: Marley & Eu - Página: 2 - Review: 9
# Livro 13: Marley & Eu - Página: 2 - Review: 10
# Livro 13: Marley & Eu - Página: 2 - Review: 11
# Livro 13: Marley & Eu - Página: 2 - Review: 12
# Livro 13: Marley & Eu - Página: 2 - Review: 13
# Livro 13: Marley & Eu - Página: 2 - Review: 14
# Livro 13: Marley & Eu - Página: 2 - Review: 15
# Livro 13: Marley & Eu - Página: 3
# Livro 13: Marley & Eu - Página: 3 - Review: 1
# Livro 13: Marley & Eu - Página: 3 - Review: 2
# Livro 13: Marley & Eu - Página: 3 - Review: 3
# Livro 13: Marley & Eu - Página: 3 - Review: 4
# Livro 13: Marley & Eu - Página: 3 - Review: 5
# Livro 14: Memória de minhas putas tristes
# Livro 14: Memória de minhas putas tristes - Página: 1
# Livro 14: Memória de minhas putas tristes - Página: 1 - Review: 1
# Livro 14: Memória de minhas putas tristes - Página: 1 - Review: 2
# Livro 14: Memória de minhas putas tristes - Página: 1 - Review: 3
# Livro 14: Memória de minhas putas tristes - Página: 1 - Review: 4
# Livro 14: Memória de minhas putas tristes - Página: 1 - Review: 5
# Livro 14: Memória de minhas putas tristes - Página: 1 - Review: 6
# Livro 14: Memória de minhas putas tristes - Página: 1 - Review: 7
# Livro 14: Memória de minhas putas tristes - Página: 1 - Review: 8
# Livro 14: Memória de minhas putas tristes - Página: 1 - Review: 9
# Livro 14: Memória de minhas putas tristes - Página: 1 - Review: 10
# Livro 14: Memória de minhas putas tristes - Página: 1 - Review: 11
# Livro 14: Memória de minhas putas tristes - Página: 1 - Review: 12
# Livro 14: Memória de minhas putas tristes - Página: 1 - Review: 13
# Livro 14: Memória de minhas putas tristes - Página: 1 - Review: 14
# Livro 14: Memória de minhas putas tristes - Página: 1 - Review: 15
# Livro 14: Memória de minhas putas tristes - Página: 2
# Livro 14: Memória de minhas putas tristes - Página: 2 - Review: 1
# Livro 14: Memória de minhas putas tristes - Página: 2 - Review: 2
# Livro 14: Memória de minhas putas tristes - Página: 2 - Review: 3
# Livro 14: Memória de minhas putas tristes - Página: 2 - Review: 4
# Livro 14: Memória de minhas putas tristes - Página: 2 - Review: 5
# Livro 14: Memória de minhas putas tristes - Página: 2 - Review: 6
# Livro 14: Memória de minhas putas tristes - Página: 2 - Review: 7
# Livro 14: Memória de minhas putas tristes - Página: 2 - Review: 8
# Livro 14: Memória de minhas putas tristes - Página: 2 - Review: 9
# Livro 14: Memória de minhas putas tristes - Página: 2 - Review: 10
# Livro 14: Memória de minhas putas tristes - Página: 2 - Review: 11
# Livro 14: Memória de minhas putas tristes - Página: 2 - Review: 12
# Livro 14: Memória de minhas putas tristes - Página: 2 - Review: 13
# Livro 14: Memória de minhas putas tristes - Página: 2 - Review: 14
# Livro 14: Memória de minhas putas tristes - Página: 2 - Review: 15
# Livro 14: Memória de minhas putas tristes - Página: 3
# Livro 14: Memória de minhas putas tristes - Página: 3 - Review: 1
# Livro 14: Memória de minhas putas tristes - Página: 3 - Review: 2
# Livro 14: Memória de minhas putas tristes - Página: 3 - Review: 3
# Livro 14: Memória de minhas putas tristes - Página: 3 - Review: 4
# Livro 14: Memória de minhas putas tristes - Página: 3 - Review: 5
# Livro 15: Perdas & Ganhos
# Livro 15: Perdas & Ganhos - Página: 1
# Livro 15: Perdas & Ganhos - Página: 1 - Review: 1
# Livro 15: Perdas & Ganhos - Página: 1 - Review: 2
# Livro 15: Perdas & Ganhos - Página: 1 - Review: 3
# Livro 15: Perdas & Ganhos - Página: 1 - Review: 4
# Livro 15: Perdas & Ganhos - Página: 1 - Review: 5
# Livro 15: Perdas & Ganhos - Página: 1 - Review: 6
# Livro 15: Perdas & Ganhos - Página: 1 - Review: 7
# Livro 15: Perdas & Ganhos - Página: 1 - Review: 8
# Livro 15: Perdas & Ganhos - Página: 1 - Review: 9
# Livro 15: Perdas & Ganhos - Página: 1 - Review: 10
# Livro 15: Perdas & Ganhos - Página: 1 - Review: 11
# Livro 15: Perdas & Ganhos - Página: 1 - Review: 12
# Livro 15: Perdas & Ganhos - Página: 1 - Review: 13
# Livro 15: Perdas & Ganhos - Página: 1 - Review: 14
# Livro 15: Perdas & Ganhos - Página: 1 - Review: 15
# Livro 15: Perdas & Ganhos - Página: 2
# Livro 15: Perdas & Ganhos - Página: 2 - Review: 1
# Livro 15: Perdas & Ganhos - Página: 2 - Review: 2
# Livro 15: Perdas & Ganhos - Página: 2 - Review: 3
# Livro 15: Perdas & Ganhos - Página: 2 - Review: 4
# Livro 15: Perdas & Ganhos - Página: 2 - Review: 5
# Livro 15: Perdas & Ganhos - Página: 2 - Review: 6
# Livro 15: Perdas & Ganhos - Página: 2 - Review: 7
# Livro 15: Perdas & Ganhos - Página: 2 - Review: 8
# Livro 15: Perdas & Ganhos - Página: 2 - Review: 9
# Livro 15: Perdas & Ganhos - Página: 2 - Review: 10
# Livro 15: Perdas & Ganhos - Página: 2 - Review: 11
# Livro 15: Perdas & Ganhos - Página: 2 - Review: 12
# Livro 15: Perdas & Ganhos - Página: 2 - Review: 13
# Livro 15: Perdas & Ganhos - Página: 2 - Review: 14
# Livro 15: Perdas & Ganhos - Página: 2 - Review: 15
# Livro 15: Perdas & Ganhos - Página: 3
# Livro 15: Perdas & Ganhos - Página: 3 - Review: 1
# Livro 15: Perdas & Ganhos - Página: 3 - Review: 2
# Livro 15: Perdas & Ganhos - Página: 3 - Review: 3
# Livro 15: Perdas & Ganhos - Página: 3 - Review: 4
# Livro 15: Perdas & Ganhos - Página: 3 - Review: 5
# Livro 15: Perdas & Ganhos - Página: 3 - Review: 6
# Livro 16: Pensar é Transgredir
# Livro 16: Pensar é Transgredir - Página: 1
# Livro 16: Pensar é Transgredir - Página: 1 - Review: 1
# Livro 16: Pensar é Transgredir - Página: 1 - Review: 2
# Livro 16: Pensar é Transgredir - Página: 1 - Review: 3
# Livro 16: Pensar é Transgredir - Página: 1 - Review: 4
# Livro 16: Pensar é Transgredir - Página: 1 - Review: 5
# Livro 16: Pensar é Transgredir - Página: 1 - Review: 6
# Livro 16: Pensar é Transgredir - Página: 1 - Review: 7
# Livro 16: Pensar é Transgredir - Página: 1 - Review: 8
# Livro 16: Pensar é Transgredir - Página: 1 - Review: 9
# Livro 16: Pensar é Transgredir - Página: 1 - Review: 10
# Livro 16: Pensar é Transgredir - Página: 1 - Review: 11
# Livro 16: Pensar é Transgredir - Página: 1 - Review: 12
# Livro 16: Pensar é Transgredir - Página: 1 - Review: 13
# Livro 16: Pensar é Transgredir - Página: 1 - Review: 14
# Livro 16: Pensar é Transgredir - Página: 1 - Review: 15
# Livro 16: Pensar é Transgredir - Página: 2
# Livro 16: Pensar é Transgredir - Página: 2 - Review: 1
# Livro 16: Pensar é Transgredir - Página: 2 - Review: 2
# Livro 16: Pensar é Transgredir - Página: 2 - Review: 3
# Livro 16: Pensar é Transgredir - Página: 2 - Review: 4
# Livro 16: Pensar é Transgredir - Página: 2 - Review: 5
# Livro 16: Pensar é Transgredir - Página: 2 - Review: 6
# Livro 16: Pensar é Transgredir - Página: 2 - Review: 7
# Livro 16: Pensar é Transgredir - Página: 2 - Review: 8
# Livro 16: Pensar é Transgredir - Página: 2 - Review: 9
# Livro 16: Pensar é Transgredir - Página: 2 - Review: 10
# Livro 16: Pensar é Transgredir - Página: 2 - Review: 11
# Livro 16: Pensar é Transgredir - Página: 2 - Review: 12
# Livro 16: Pensar é Transgredir - Página: 2 - Review: 13
# Livro 16: Pensar é Transgredir - Página: 2 - Review: 14
# Livro 16: Pensar é Transgredir - Página: 2 - Review: 15
# Livro 16: Pensar é Transgredir - Página: 3
# Livro 16: Pensar é Transgredir - Página: 3 - Review: 1
# Livro 16: Pensar é Transgredir - Página: 3 - Review: 2
# Livro 16: Pensar é Transgredir - Página: 3 - Review: 3
# Livro 16: Pensar é Transgredir - Página: 3 - Review: 4
# Livro 16: Pensar é Transgredir - Página: 3 - Review: 5
# Livro 17: O rio do meio
# Livro 17: O rio do meio - Página: 1
# Livro 17: O rio do meio - Página: 1 - Review: 1
# Livro 17: O rio do meio - Página: 1 - Review: 2
# Livro 17: O rio do meio - Página: 1 - Review: 3
# Livro 17: O rio do meio - Página: 1 - Review: 4
# Livro 17: O rio do meio - Página: 1 - Review: 5
# Livro 18: O Monge e O Executivo
# Livro 18: O Monge e O Executivo - Página: 1
# Livro 18: O Monge e O Executivo - Página: 1 - Review: 1
# Livro 18: O Monge e O Executivo - Página: 1 - Review: 2
# Livro 18: O Monge e O Executivo - Página: 1 - Review: 3
# Livro 18: O Monge e O Executivo - Página: 1 - Review: 4
# Livro 18: O Monge e O Executivo - Página: 1 - Review: 5
# Livro 18: O Monge e O Executivo - Página: 1 - Review: 6
# Livro 18: O Monge e O Executivo - Página: 1 - Review: 7
# Livro 18: O Monge e O Executivo - Página: 1 - Review: 8
# Livro 18: O Monge e O Executivo - Página: 1 - Review: 9
# Livro 18: O Monge e O Executivo - Página: 1 - Review: 10
# Livro 18: O Monge e O Executivo - Página: 1 - Review: 11
# Livro 18: O Monge e O Executivo - Página: 1 - Review: 12
# Livro 18: O Monge e O Executivo - Página: 1 - Review: 13
# Livro 18: O Monge e O Executivo - Página: 1 - Review: 14
# Livro 18: O Monge e O Executivo - Página: 1 - Review: 15
# Livro 18: O Monge e O Executivo - Página: 2
# Livro 18: O Monge e O Executivo - Página: 2 - Review: 1
# Livro 18: O Monge e O Executivo - Página: 2 - Review: 2
# Livro 18: O Monge e O Executivo - Página: 2 - Review: 3
# Livro 18: O Monge e O Executivo - Página: 2 - Review: 4
# Livro 18: O Monge e O Executivo - Página: 2 - Review: 5
# Livro 18: O Monge e O Executivo - Página: 2 - Review: 6
# Livro 18: O Monge e O Executivo - Página: 2 - Review: 7
# Livro 18: O Monge e O Executivo - Página: 2 - Review: 8
# Livro 18: O Monge e O Executivo - Página: 2 - Review: 9
# Livro 18: O Monge e O Executivo - Página: 2 - Review: 10
# Livro 18: O Monge e O Executivo - Página: 2 - Review: 11
# Livro 18: O Monge e O Executivo - Página: 2 - Review: 12
# Livro 18: O Monge e O Executivo - Página: 2 - Review: 13
# Livro 18: O Monge e O Executivo - Página: 2 - Review: 14
# Livro 18: O Monge e O Executivo - Página: 2 - Review: 15
# Livro 18: O Monge e O Executivo - Página: 3
# Livro 18: O Monge e O Executivo - Página: 3 - Review: 1
# Livro 18: O Monge e O Executivo - Página: 3 - Review: 2
# Livro 18: O Monge e O Executivo - Página: 3 - Review: 3
# Livro 18: O Monge e O Executivo - Página: 3 - Review: 4
# Livro 18: O Monge e O Executivo - Página: 3 - Review: 5
# Livro 19: O amor é a melhor estratégia
# Livro 19: O amor é a melhor estratégia - Página: 1
# Livro 19: O amor é a melhor estratégia - Página: 1 - Review: 1
# Livro 19: O amor é a melhor estratégia - Página: 1 - Review: 2
# Livro 19: O amor é a melhor estratégia - Página: 1 - Review: 3
# Livro 19: O amor é a melhor estratégia - Página: 1 - Review: 4
# Livro 20: A primeira impressão é a que fica
# Livro 20: A primeira impressão é a que fica - Página: 1
# Livro 20: A primeira impressão é a que fica - Página: 1 - Review: 1
# Livro 20: A primeira impressão é a que fica - Página: 1 - Review: 2
# Livro 20: A primeira impressão é a que fica - Página: 1 - Review: 3

# %%
df_reviews = pd.DataFrame(reviews)
df_livros = pd.DataFrame(livros)

# %%
df_reviews.value_counts('book')
# Out:
# book
# A Menina que Roubava Livros                35
# Memória de minhas putas tristes            35
# Perdas & Ganhos                            35
# Pensar é Transgredir                       35
# Pai Rico Pai Pobre                         35
# Operação Cavalo de Tróia 1                 35
# O Monge e O Executivo                      35
# O Caçador de Pipas                         35
# O Alquimista                               35
# Marley & Eu                                35
# Ilusões                                    35
# Fernão Capelo Gaivota                      35
# Ensaio Sobre a Cegueira                    35
# Quem Mexeu No Meu Queijo?                  35
# Investimentos                              20
# O rio do meio                               4
# Atitude                                     4
# O amor é a melhor estratégia                3
# A primeira impressão é a que fica           2
# Atitude! 2 - O que você está esperando?     1
# dtype: int64

# %%
df_reviews.value_counts('user_id').head(20)
# Out:
# user_id
# 750665-renata-ccs        5
# 2249547-fran             3
# 360744-ludy              3
# 3799-marcos-bassini      3
# 1459792-janeladelivro    3
# 8-renanlima              2
# 3647026-cristiano        2
# 6650546-aprendilendo_    2
# 767891-luciane           2
# 142822-shirlei           2
# 8096443-chacon           2
# 241359-leia-viana        2
# 6727372-tania            2
# 375250-clio              2
# 5319915-cinara...        2
# 2224820-keila            2
# 7928582-gustavo          2
# 7879540-mila             2
# 4449-kassya              2
# 7640667-mari             2
# dtype: int64

# %%
df_livros.head()
# Out:
#             author                        book  \
# 0    José Saramago     Ensaio Sobre a Cegueira
# 1  Khaled Hosseini          O Caçador de Pipas
# 2     Paulo Coelho                O Alquimista
# 3     Richard Bach       Fernão Capelo Gaivota
# 4    J. J. Benítez  Operação Cavalo de Tróia 1
#
#                                                               link  \
# 0  https://www.skoob.com.br/livro/resenhas/1/mais-gostaram/mpage:1
# 1  https://www.skoob.com.br/livro/resenhas/2/mais-gostaram/mpage:1
# 2  https://www.skoob.com.br/livro/resenhas/3/mais-gostaram/mpage:1
# 3  https://www.skoob.com.br/livro/resenhas/4/mais-gostaram/mpage:1
# 4  https://www.skoob.com.br/livro/resenhas/5/mais-gostaram/mpage:1
#
#    livro_numero
# 0             1
# 1             2
# 2             3
# 3             4
# 4             5

# %%
df_livros.tail()
# Out:
#              author                               book  \
# 15         Lya Luft               Pensar é Transgredir
# 16         Lya Luft                      O rio do meio
# 17  James C. Hunter              O Monge e O Executivo
# 18      Tim Sanders       O amor é a melhor estratégia
# 19     Ann Demarais  A primeira impressão é a que fica
#
#                                                                 link  \
# 15  https://www.skoob.com.br/livro/resenhas/16/mais-gostaram/mpage:1
# 16  https://www.skoob.com.br/livro/resenhas/17/mais-gostaram/mpage:1
# 17  https://www.skoob.com.br/livro/resenhas/18/mais-gostaram/mpage:1
# 18  https://www.skoob.com.br/livro/resenhas/19/mais-gostaram/mpage:1
# 19  https://www.skoob.com.br/livro/resenhas/20/mais-gostaram/mpage:1
#
#     livro_numero
# 15            16
# 16            17
# 17            18
# 18            19
# 19            20

# %%
df_livros.head(2)
# Out:
#             author                     book  \
# 0    José Saramago  Ensaio Sobre a Cegueira
# 1  Khaled Hosseini       O Caçador de Pipas
#
#                                                               link  \
# 0  https://www.skoob.com.br/livro/resenhas/1/mais-gostaram/mpage:1
# 1  https://www.skoob.com.br/livro/resenhas/2/mais-gostaram/mpage:1
#
#    livro_numero
# 0             1
# 1             2

# %%
df_reviews.head(2)
# Out:
#           author                     book  \
# 0  José Saramago  Ensaio Sobre a Cegueira
# 1  José Saramago  Ensaio Sobre a Cegueira
#
#                                                               link  \
# 0  https://www.skoob.com.br/livro/resenhas/1/mais-gostaram/mpage:1
# 1  https://www.skoob.com.br/livro/resenhas/1/mais-gostaram/mpage:1
#
#           review_id                  user_id livro_pagina_posicao  rating  \
# 0    resenha8521829    281809-fran-kotipelto                1-1-1     5.0
# 1  resenha117253217  5017139-daniel.schaefer                1-1-2     5.0
#
#                                review_title  \
# 0  Little white shadows sparkle and glisten
# 1                    TORNOU-SE MEU FAVORITO
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              review
# 0                                                                                                                                                            \n"Este é um livro francamente terrível com o qual eu quero que o leitor sofra tanto como eu sofri ao escrevê-lo. Nele se descreve uma longa tortura. É um livro brutal e violento e é simultaneamente uma das experiências mais dolorosas da minha vida. São 300 páginas de constante aflição. Através da escrita, tentei dizer que não somos bons e que é preciso que tenhamos coragem para reconhecer isso." José Saramago.\n\nEnsaio Sobre a Cegueira conta a história de uma inédita epidemia de cegueira, inexplicável, que se abate sobre uma cidade não identificada. Tal "cegueira branca" - assim chamada, pois as pessoas infectadas passam a ver apenas uma superfície leitosa - manifesta-se primeiramente em um homem no trânsito e, lentamente, espalha-se pelo país. Aos poucos, todos acabam cegos e reduzidos a meros seres lutando por suas necessidades básicas, expondo seus instintos primários. À medida que os afetados pela epidemia são colocados em quarentena e os serviços do Estado começam a falhar, a trama segue a mulher de um médico, a única pessoa que não é afetada pela doença.\n\nO foco principal do livro não é de maneira nenhuma tentar desvendar a causa da doença ou sua cura, mas mostrar o desmoronar completo da sociedade que, perde tudo aquilo que considera civilizado,fazendo com que a os afetados pela epidemia mostrem aquilo que no fundo no fundo todos os seres humanos são: "tremendos filhos da puta".\n\nAo mesmo tempo em que vemos o colapso da civilização, um grupo de internos tenta reencontrar a humanidade perdida. O brilho branco da cegueira ilumina as percepções das personagens principais, e a história torna-se não só um registro da sobrevivência física das multidões cegas, mas, também, dos seus mundos emocionais e da dignidade que tentam manter. Mais do que olhar, importa reparar no outro. Só dessa forma o homem se humaniza novamente,voltando a perceber como é doce e suave o cheiro da chuva,o quão valioso é um abraço sincero em um amigo,o sentido de viver em grupo,um mundo cego,porém altruísta,onde chorar não é vergonha,ter medo é uma dádiva,e viver é mais humano.Distante da rotina vagabunda de um cotidiano medíocre que nos habituamos a viver infelizmente.Mas que graças à José Saramago,a cegueira nos fez enxergar!
# 1  Não havia época melhor para ler, do que no meio da pandemia, não é verdade? Deixo registrado que o li na metade de 2020 e que foi muito importante para mim. \n\nEnsaio Sobre a Cegueira é um livro sobre os desastres acometidos pela humanidade, ao não estar preparada para uma avassaladora epidemia, onde as pessoas ficam cegas. Ninguém estava preparado para algo desse porte e o caos se estabelece entre todos. Temos os personagens definidos de forma que muitas vezes, a sociedade os reduz, como por exemplo "A Mulher do Médico" ou "O Ladrão de Carros", e esses personagens são extremamente bem construídos, especialmente A Mulher do Médico, que para mim é a melhor personagem da obra, e devo arriscar dizer, uma das melhores que já vi na Literatura. O questionamento dela, quando comete uma atrocidade (que não revelarei por motivos de não entregar a trama), é certamente a parte chave, fundamental da obra.\n\nJosé Saramago tenta nos colocar sobre a pergunta "Mas e a nossa sociedade atual, já não estamos cegos?" Para quantos assuntos sociais nós estamos cegos? Pego como exemplo, o fato de termos enquadrado assuntos importantíssimos como a Sexualidade, reduzindo-o como se fosse uma pauta política? E quando nos deixamos cegar, concordando com essas opiniões? A respeito da quarentena atual, quantas vezes ficamos cegos perante atitudes alheias e principalmente, as nossas atitudes. E será que estávamos preparados para um isolamento? Pois é... \n\nA cegueira é uma metáfora belíssima, e tratar do assunto de como o ser humano se comporta em uma situação extrema, é algo complicado ao meu ver. O escritor aqui faz de forma impecável. Tudo nesse livro é bem construído, e até a mudança nas regras gramaticais são como um deboche do autor, assim como uma certa licença poética, revelando o quão estamos regrados a todos os dogmas que nos foi ensinado. \n\nOBRA GENIAL! Putz, não importa o gênero literário que você curte, leia esse livro. Porém devo te alertar, sobre dois gatilhos dentro do livro: abuso sexual e suicídio. É um livro pesadíssimo, e quem tem o mínimo de estômago, deve apreciar a obra como um todo. Ela se dispõe a mostrar de forma nua e crua, o que o ser humano é capaz, e das consequências do que ele não se prepara para enfrentar. \n\nSe gostaram, segue no Insta, pretendo falar mais dela em breve: @escritordanielschaefer site: https://www.instagram.com/escritordanielschaefer/
